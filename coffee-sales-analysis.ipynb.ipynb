# %%
import pandas as pd

df = pd.read_csv("Copy of Afficionado Coffee Roasters.csv")
df.head()
# Out:
#    transaction_id  year transaction_time  transaction_qty  store_id  \
# 0               1  2025         07:06:11                2         5
# 1               2  2025         07:08:56                2         5
# 2               3  2025         07:14:04                2         5
# 3               4  2025         07:20:24                1         5
# 4               5  2025         07:22:41                2         5
#
#     store_location  product_id  unit_price    product_category  \
# 0  Lower Manhattan          32         3.0              Coffee
# 1  Lower Manhattan          57         3.1                 Tea
# 2  Lower Manhattan          59         4.5  Drinking Chocolate
# 3  Lower Manhattan          22         2.0              Coffee
# 4  Lower Manhattan          57         3.1                 Tea
#
#             product_type               product_detail
# 0  Gourmet brewed coffee                  Ethiopia Rg
# 1        Brewed Chai tea     Spicy Eye Opener Chai Lg
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df = pd.read_csv()(" Copy of Afficionado Coffee Roasters.csv")
#       2 df.head()
#
# TypeError: read_csv() missing 1 required positional argument: 'filepath_or_buffer'

# %%
import os
os.listdir()
# Out:
# ['.anaconda',
#  '.cfx',
#  '.conda',
#  '.condarc',
#  '.continuum',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.ms-ad',
#  '.vscode',
#  'anaconda3',
#  'anaconda4',
#  'anaconda_projects',
#  'ansel',
#  'AppData',
#  'Application Data',
#  'Contacts',
#  'Cookies',
#  'Copy of Afficionado Coffee Roasters.csv',
#  'Copy of Afficionado Coffee Roasters.xlsx',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'first program.py',
#  'firstprogram.py',
#  'Links',
#  'Local Settings',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{a2332f18-cdbf-11ec-8680-002248483d79}.TM.blf',
#  'NTUSER.DAT{a2332f18-cdbf-11ec-8680-002248483d79}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{a2332f18-cdbf-11ec-8680-002248483d79}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'OneDrive',
#  'PrintHood',
#  'Recent',
#  'Saved Games',
#  'Searches',
#  'SendTo',
# ...

# %%
import pandas as pd

df = pd.read_csv("Copy of Afficionado Coffee Roasters.csv")
df.head()
# Out:
#    transaction_id  year transaction_time  transaction_qty  store_id  \
# 0               1  2025         07:06:11                2         5
# 1               2  2025         07:08:56                2         5
# 2               3  2025         07:14:04                2         5
# 3               4  2025         07:20:24                1         5
# 4               5  2025         07:22:41                2         5
#
#     store_location  product_id  unit_price    product_category  \
# 0  Lower Manhattan          32         3.0              Coffee
# 1  Lower Manhattan          57         3.1                 Tea
# 2  Lower Manhattan          59         4.5  Drinking Chocolate
# 3  Lower Manhattan          22         2.0              Coffee
# 4  Lower Manhattan          57         3.1                 Tea
#
#             product_type               product_detail
# 0  Gourmet brewed coffee                  Ethiopia Rg
# 1        Brewed Chai tea     Spicy Eye Opener Chai Lg
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of         transaction_id  year transaction_time  transaction_qty  store_id  \
# 0                    1  2025         07:06:11                2         5
# 1                    2  2025         07:08:56                2         5
# 2                    3  2025         07:14:04                2         5
# 3                    4  2025         07:20:24                1         5
# 4                    5  2025         07:22:41                2         5
# ...                ...   ...              ...              ...       ...
# 149111          149452  2025         20:18:41                2         8
# 149112          149453  2025         20:25:10                2         8
# 149113          149454  2025         20:31:34                1         8
# 149114          149455  2025         20:57:19                1         8
# 149115          149456  2025         20:57:19                2         8
#
# ...

# %%
df.describe()
# Out:
#        transaction_id      year  transaction_qty       store_id  \
# count   149116.000000  149116.0    149116.000000  149116.000000
# mean     74737.371872    2025.0         1.438276       5.342063
# std      43153.600016       0.0         0.542509       2.074241
# min          1.000000    2025.0         1.000000       3.000000
# 25%      37335.750000    2025.0         1.000000       3.000000
# 50%      74727.500000    2025.0         1.000000       5.000000
# 75%     112094.250000    2025.0         2.000000       8.000000
# max     149456.000000    2025.0         8.000000       8.000000
#
#           product_id     unit_price
# count  149116.000000  149116.000000
# mean       47.918607       3.382219
# std        17.930020       2.658723
# min         1.000000       0.800000
# 25%        33.000000       2.500000
# 50%        47.000000       3.000000
# 75%        60.000000       3.750000
# max        87.000000      45.000000

# %%
df.isnull().sum()
# Out:
# transaction_id      0
# year                0
# transaction_time    0
# transaction_qty     0
# store_id            0
# store_location      0
# product_id          0
# unit_price          0
# product_category    0
# product_type        0
# product_detail      0
# dtype: int64

# %%
df['product_category'].value_counts()
# Out:
# product_category
# Coffee                58416
# Tea                   45449
# Bakery                22796
# Drinking Chocolate    11468
# Flavours               6790
# Coffee beans           1753
# Loose Tea              1210
# Branded                 747
# Packaged Chocolate      487
# Name: count, dtype: int64

# %%
df['store_location'].value_counts()
# Out:
# store_location
# Hell's Kitchen     50735
# Astoria            50599
# Lower Manhattan    47782
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
type('df')
# Out:
# str

# %%
import pandas as pd

df = pd.read_csv("Copy of Afficionado Coffee Roasters.csv")
df.head()
# Out:
#    transaction_id  year transaction_time  transaction_qty  store_id  \
# 0               1  2025         07:06:11                2         5
# 1               2  2025         07:08:56                2         5
# 2               3  2025         07:14:04                2         5
# 3               4  2025         07:20:24                1         5
# 4               5  2025         07:22:41                2         5
#
#     store_location  product_id  unit_price    product_category  \
# 0  Lower Manhattan          32         3.0              Coffee
# 1  Lower Manhattan          57         3.1                 Tea
# 2  Lower Manhattan          59         4.5  Drinking Chocolate
# 3  Lower Manhattan          22         2.0              Coffee
# 4  Lower Manhattan          57         3.1                 Tea
#
#             product_type               product_detail
# 0  Gourmet brewed coffee                  Ethiopia Rg
# 1        Brewed Chai tea     Spicy Eye Opener Chai Lg
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [raw]
# df.columns

# %%
df.columns = df.columns.str.strip().str.lower().str.replace("","_")
df.columns
# Out:
# Index(['___t___r___a___n___s___a___c___t___i___o___n_______i___d___',
#        '___y___e___a___r___',
#        '___t___r___a___n___s___a___c___t___i___o___n_______t___i___m___e___',
#        '___t___r___a___n___s___a___c___t___i___o___n_______q___t___y___',
#        '___s___t___o___r___e_______i___d___',
#        '___s___t___o___r___e_______l___o___c___a___t___i___o___n___',
#        '___p___r___o___d___u___c___t_______i___d___',
#        '___u___n___i___t_______p___r___i___c___e___',
#        '___p___r___o___d___u___c___t_______c___a___t___e___g___o___r___y___',
#        '___p___r___o___d___u___c___t_______t___y___p___e___',
#        '___p___r___o___d___u___c___t_______d___e___t___a___i___l___'],
#       dtype='object')

# %%
df = df.rename(columns={'___t___r___a___n___s___a___c___t___i___o___n_______q___t___y___':
                        'transaction_qty',
                        '___u___n___i___t_______p___r___i___c___e___':'unit_price'})

# %%
import pandas as pd

df = pd.read_csv("Copy of Afficionado Coffee Roasters.csv")
df.head()
# Out:
#    transaction_id  year transaction_time  transaction_qty  store_id  \
# 0               1  2025         07:06:11                2         5
# 1               2  2025         07:08:56                2         5
# 2               3  2025         07:14:04                2         5
# 3               4  2025         07:20:24                1         5
# 4               5  2025         07:22:41                2         5
#
#     store_location  product_id  unit_price    product_category  \
# 0  Lower Manhattan          32         3.0              Coffee
# 1  Lower Manhattan          57         3.1                 Tea
# 2  Lower Manhattan          59         4.5  Drinking Chocolate
# 3  Lower Manhattan          22         2.0              Coffee
# 4  Lower Manhattan          57         3.1                 Tea
#
#             product_type               product_detail
# 0  Gourmet brewed coffee                  Ethiopia Rg
# 1        Brewed Chai tea     Spicy Eye Opener Chai Lg
# ...

# %%
df.columns = df.columns.str.strip().str.lower().str.replace("","_")

# %%
import pandas as pd

df = pd.read_csv("Copy of Afficionado Coffee Roasters.csv")
df.head()
# Out:
#    transaction_id  year transaction_time  transaction_qty  store_id  \
# 0               1  2025         07:06:11                2         5
# 1               2  2025         07:08:56                2         5
# 2               3  2025         07:14:04                2         5
# 3               4  2025         07:20:24                1         5
# 4               5  2025         07:22:41                2         5
#
#     store_location  product_id  unit_price    product_category  \
# 0  Lower Manhattan          32         3.0              Coffee
# 1  Lower Manhattan          57         3.1                 Tea
# 2  Lower Manhattan          59         4.5  Drinking Chocolate
# 3  Lower Manhattan          22         2.0              Coffee
# 4  Lower Manhattan          57         3.1                 Tea
#
#             product_type               product_detail
# 0  Gourmet brewed coffee                  Ethiopia Rg
# 1        Brewed Chai tea     Spicy Eye Opener Chai Lg
# ...

# %%
df.columns
# Out:
# Index(['transaction_id', 'year', 'transaction_time', 'transaction_qty',
#        'store_id', 'store_location', 'product_id', 'unit_price',
#        'product_category', 'product_type', 'product_detail'],
#       dtype='object')

# %%
df['revenue'] = df['transaction_qty']*df['unit_price']

# %%
df.head()
# Out:
#    transaction_id  year transaction_time  transaction_qty  store_id  \
# 0               1  2025         07:06:11                2         5
# 1               2  2025         07:08:56                2         5
# 2               3  2025         07:14:04                2         5
# 3               4  2025         07:20:24                1         5
# 4               5  2025         07:22:41                2         5
#
#     store_location  product_id  unit_price    product_category  \
# 0  Lower Manhattan          32         3.0              Coffee
# 1  Lower Manhattan          57         3.1                 Tea
# 2  Lower Manhattan          59         4.5  Drinking Chocolate
# 3  Lower Manhattan          22         2.0              Coffee
# 4  Lower Manhattan          57         3.1                 Tea
#
#             product_type               product_detail  revenue
# 0  Gourmet brewed coffee                  Ethiopia Rg      6.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149116 entries, 0 to 149115
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   transaction_id    149116 non-null  int64
#  1   year              149116 non-null  int64
#  2   transaction_time  149116 non-null  object
#  3   transaction_qty   149116 non-null  int64
#  4   store_id          149116 non-null  int64
#  5   store_location    149116 non-null  object
#  6   product_id        149116 non-null  int64
#  7   unit_price        149116 non-null  float64
#  8   product_category  149116 non-null  object
#  9   product_type      149116 non-null  object
#  10  product_detail    149116 non-null  object
#  11  revenue           149116 non-null  float64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 13.7+ MB

# %%
df['transaction_qty'] =df['transaction_qty'].astype(float)

# %%
df['unit_price'] =df['unit_price'].astype(float)

# %%
df['revenue'] = df['transaction_qty']*df['unit_price']
df.head()
# Out:
#    transaction_id  year transaction_time  transaction_qty  store_id  \
# 0               1  2025         07:06:11              2.0         5
# 1               2  2025         07:08:56              2.0         5
# 2               3  2025         07:14:04              2.0         5
# 3               4  2025         07:20:24              1.0         5
# 4               5  2025         07:22:41              2.0         5
#
#     store_location  product_id  unit_price    product_category  \
# 0  Lower Manhattan          32         3.0              Coffee
# 1  Lower Manhattan          57         3.1                 Tea
# 2  Lower Manhattan          59         4.5  Drinking Chocolate
# 3  Lower Manhattan          22         2.0              Coffee
# 4  Lower Manhattan          57         3.1                 Tea
#
#             product_type               product_detail  revenue
# 0  Gourmet brewed coffee                  Ethiopia Rg      6.0
# ...

# %%
df['revenue'] = df['transaction_qty']*df['unit_price']

# %%
df.head()
# Out:
#    transaction_id  year transaction_time  transaction_qty  store_id  \
# 0               1  2025         07:06:11              2.0         5
# 1               2  2025         07:08:56              2.0         5
# 2               3  2025         07:14:04              2.0         5
# 3               4  2025         07:20:24              1.0         5
# 4               5  2025         07:22:41              2.0         5
#
#     store_location  product_id  unit_price    product_category  \
# 0  Lower Manhattan          32         3.0              Coffee
# 1  Lower Manhattan          57         3.1                 Tea
# 2  Lower Manhattan          59         4.5  Drinking Chocolate
# 3  Lower Manhattan          22         2.0              Coffee
# 4  Lower Manhattan          57         3.1                 Tea
#
#             product_type               product_detail  revenue
# 0  Gourmet brewed coffee                  Ethiopia Rg      6.0
# ...

# %%
df.groupby('product_category')['revenue'].sum()
# Out:
# product_category
# Bakery                 82315.64
# Branded                13607.00
# Coffee                269952.45
# Coffee beans           40085.25
# Drinking Chocolate     72416.00
# Flavours                8408.80
# Loose Tea              11213.60
# Packaged Chocolate      4407.64
# Tea                   196405.95
# Name: revenue, dtype: float64

# %%
df['product_category'] =df['product_category'].str.strip().str.lower()

# %%
df['product_category'] =df['product_category'].replace({'loose tea':'tea'})

# %%
import matplotlib.pyplot as plt

df.groupby('product_category')['revenue'].sum().plot(kind='bar')
plt.xticks(rotation=45)
plt.show()

# %%
df['product_category'].unique()
# Out:
# array(['coffee', 'tea', 'drinking chocolate', 'bakery', 'flavours',
#        'coffee beans', 'packaged chocolate', 'branded'], dtype=object)

# %%
df.groupby('product_category')['revenue'].sum().sort_values(ascending=False)
# Out:
# product_category
# coffee                269952.45
# tea                   207619.55
# bakery                 82315.64
# drinking chocolate     72416.00
# coffee beans           40085.25
# branded                13607.00
# flavours                8408.80
# packaged chocolate      4407.64
# Name: revenue, dtype: float64

# %%
df.groupby('product_detail')['revenue'].sum().sort_values(ascending=False).head()
# Out:
# product_detail
# Sustainably Grown Organic Lg    21151.75
# Dark chocolate Lg               21006.00
# Latte Rg                        19112.25
# Cappuccino Lg                   17641.75
# Morning Sunrise Chai Lg         17384.00
# Name: revenue, dtype: float64

# %%
df.groupby('store_location')['revenue'].sum().sort_values(ascending=False)
# Out:
# store_location
# Hell's Kitchen     236511.17
# Astoria            232243.91
# Lower Manhattan    230057.25
# Name: revenue, dtype: float64
